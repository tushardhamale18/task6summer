# %%
import cv2
import numpy as np
import threading
import os

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = './faces/user/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
# Out:
# <>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-1-f5c4e66e3bf3>:17: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Collecting Samples Complete

# %%
cap.release()

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path = './faces/user/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()
TD_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
TD_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained sucessefully")
# Out:
# Model trained sucessefully

# %%
#mail function
def mail():
    os.system("python mail.py")
#Whatsapp function
def whatsapp():
    os.system("python whatsapp.py")
def ec2():
    os.system("terraform apply -auto-approve")

# %%
import cv2
import numpy as np
import os


face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = TD_model.predict(face)
        # harry_model.predict(face)
        
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/650) )
            display_string = str(confidence) + '% Confident it is User'
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence > 90:
            cv2.putText(image, "Hey Tushar", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
           
             #For sending mail
            mail=threading.Thread(target=mail)
            mail.start()
            #For Whatsapp
            whatsapp=threading.Thread(target=whatsapp)
            whatsapp.start()
            
        
        
        else:
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
            ec2=threading.Thread(target=ec2)
            ec2.start()
           

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-4-8985ae402578>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-12Thread-13:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-14:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-18:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-22Exception in thread :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-23:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-27:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-29:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-34Thread-35:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-37:
# Thread-36Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-46:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-48:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-49:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-50:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-52Thread-53:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-54:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-56:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-58:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-60:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-61:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-62:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-63:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-64:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-65:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-66:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-67:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-68:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-69:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-70:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-71:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-72:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-73:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-74:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-75:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-76:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-77:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-78:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-79:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-80:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-81:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-83:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-82:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-84:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-85:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-86:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-87:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-88:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-89:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-90:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-91:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-92:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-93:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-94:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-95:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-96:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-97:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-98:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-99:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-100:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-101:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-102:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-103:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-104Thread-105:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#       File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-106:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-107:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-108:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-109:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-110:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-111:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-112:
# Exception in thread Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-113:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-114Thread-115:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-116:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-117:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-118:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-119:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-121:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-120:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-122:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-123:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-124:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-125:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-126:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-127:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-128:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-129:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-130:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-131:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-132:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-133:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-134:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-135:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-136:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-137:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-138:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-139:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-140Thread-141:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-142:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-143:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-144:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-145:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-146:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-147:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-148Thread-149:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-150:
# Exception in thread Thread-151:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-152:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-153:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-154:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-155:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-156:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-157:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# ...
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1956:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1957:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1958:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1959:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1961:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1960:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1962:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1963:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1964:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1965:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1966:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1967:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1968:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1969:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1970:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1971:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1972:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1973:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1974:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1975:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1976:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1977:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1978:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1979:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1980:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1981:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1982:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1983:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1984:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1985:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1986:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1987:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1988:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1989:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1990:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-1992:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Thread-1991:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#         self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1993:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1994:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1995:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1996:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1997:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-1998:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Thread-1999:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-2000:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# Exception in thread Exception in thread Thread-2001Thread-2002:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#         self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
# self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError:     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
# 'Thread' object is not callable
# Exception in thread Thread-2003:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-2004:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\DELL\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
#     self._target(*self._args, **self._kwargs)
# TypeError: 'Thread' object is not callable
